# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dff=pd.read_csv('IRIS.csv')

# %%
dff.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
dff.shape
# Out:
# (150, 5)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dff.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
dff.isnull().values.any()
# Out:
# False

# %%
dff.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
corr=dff.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
corr=dff.corr()
sns.heatmap(corr,xticklabels=corr.columns.values,yticklabels=corr.columns.values);

# %%
dff["species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dff["species"].nunique()
# Out:
# 3

# %%
sns.scatterplot(x="sepal_width",y="sepal_length",data=dff,color="purple");

# %%
sns.jointplot(x="sepal_width",y="sepal_length",data=dff,color="brown");

# %%
sns.jointplot(x = dff["sepal_length"], y = dff["sepal_width"],kind ="kde", shade = "True", color = "black");

# %%
sns.scatterplot(x="petal_width",y="petal_length",hue="species",data=dff);

# %%
sns.lmplot(x="petal_width",y="petal_length",data=dff);

# %%
dff.corr()["petal_width"]["petal_length"]
# Out:
# 0.9627570970509662

# %%
dff["total_length"]=dff["petal_length"]+dff["sepal_length"]

# %%
dff["total_length"].mean()
# Out:
# 9.602000000000004

# %%
dff["total_length"].std()
# Out:
# 2.5191739884121978

# %%
dff["sepal_length"].max()
# Out:
# 7.9

# %%
dff[(dff["sepal_length"]>5) & (dff["species"]=="Setosa")]
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species, total_length]
# Index: []

# %%
dff[(dff["petal_length"] < 5) & (dff["species"] == "Virginica")][["sepal_length","sepal_width"]]
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width]
# Index: []

# %%
dff.groupby(["species"]).mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width  \
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026
#
#                  total_length
# species
# Iris-setosa             6.470
# Iris-versicolor        10.196
# Iris-virginica         12.140

# %%
dff.groupby(["species"])["petal_length"].std()
# Out:
# species
# Iris-setosa        0.173511
# Iris-versicolor    0.469911
# Iris-virginica     0.551895
# Name: petal_length, dtype: float64
